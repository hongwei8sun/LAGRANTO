# %%
import xarray as xr

# %%
year = "2000"

# %%
ERA5_file  = xr.open_dataset('/n/home12/hongwei/Hongwei_holyscratch01/P_file_test/ERA5_UVW_'+year+'_01.grib', \
                             engine='cfgrib')


lat_ERA5 = ERA5_file['latitude']
lon_ERA5 = ERA5_file['longitude']

U_ERA5 = ERA5_file['u']
V_ERA5 = ERA5_file['v']
W_ERA5 = ERA5_file['w']

# %%
# ERA5_file

# %%
P_file  = xr.open_dataset('/n/home12/hongwei/Hongwei_holyscratch01/P_file_test/P'+year+'0101_00.nc')

lat_P = P_file['lat']
lon_P = P_file['lon']

U_P = P_file['U']
V_P = P_file['V']
W_P = P_file['OMEGA']
T_P = P_file['T']

# %%
# P_file

# %%
# P_file2 = xr.open_dataset('/n/home12/hongwei/Hongwei_holyscratch01/P_file_test/P'+year+'0101_00_new2.nc')

# U_P2 = P_file2['U']
# V_P2 = P_file2['V']
# W_P2 = P_file2['OMEGA']
# T_P2 = P_file2['T']

# %%
# P_file2

# %%
# print("ERA:")
# print(lat_ERA5[:].values)
# print(U_ERA5[0,:,0].values)

# print("P:")
# print(lat_P[:].values)
# print(U_P[0,0,:,0].values)

# %%
U_ERA5[0,:,:].plot();

# %%
U_P[0,0,:,:].plot();

# %%
U_P2[0,0,:,:].plot();
